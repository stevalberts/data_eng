# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-BD0225EN-SkillsNetwork/images/IDSN-logo.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# # **Introduction to SparkSQL**

# %% [markdown]
# Estimated time needed: **15** minutes

# %% [markdown]
# This lab goes over the basic operations of Apache SparkSQL.

# %% [markdown]
# ![](http://spark.apache.org/images/spark-logo.png)

# %% [markdown]
# ## Objectives

# %% [markdown]
# Spark SQL is a Spark module for structured data processing. It is sed to query structured data inside Spark programs, using either SQL or a familiar DataFrame API.
#
# After completing this lab you will be able to:

# %% [markdown]
# * Load a data file into a dataframe
# * Create a Table View for the dataframe
# * Run basic SQL queries and aggregate data on the table view
# * Create a Pandas UDF to perform columnar operations

# %% [markdown]
# ----

# %% [markdown]
# ## Setup

# %% [markdown]
# For this lab, we are going to be using Python and Spark (PySpark). These libraries should be installed in your lab environment or in SN Labs. Pandas is a popular data science package for Python. In this lab, we use Pandas to load a CSV file from disc to a pandas dataframe in memory. PySpark is the Spark API for Python. In this lab, we use PySpark to initialize the spark context.

# %%
# Installing required packages
# !pip install pyspark
# !pip install findspark
# !pip install pyarrow==0.14.1 
# !pip install pandas
# !pip install numpy==1.19.5
# Out:
# Requirement already satisfied: pyspark in /Users/stevenogwal/development/ml_eng/.venv/lib/python3.11/site-packages (3.5.3)
# Requirement already satisfied: py4j==0.10.9.7 in /Users/stevenogwal/development/ml_eng/.venv/lib/python3.11/site-packages (from pyspark) (0.10.9.7)
# Requirement already satisfied: findspark in /Users/stevenogwal/development/ml_eng/.venv/lib/python3.11/site-packages (2.0.1)
# ERROR: Could not find a version that satisfies the requirement pyarrow==0.14.1 (from versions: 0.9.0, 0.10.0, 0.11.0, 0.11.1, 0.12.0, 0.12.1, 0.13.0, 0.14.0, 0.15.1, 0.16.0, 0.17.0, 0.17.1, 1.0.0, 1.0.1, 2.0.0, 3.0.0, 4.0.0, 4.0.1, 5.0.0, 6.0.0, 6.0.1, 7.0.0, 8.0.0, 9.0.0, 10.0.0, 10.0.1, 11.0.0, 12.0.0, 12.0.1, 13.0.0, 14.0.0, 14.0.1, 14.0.2, 15.0.0, 15.0.1, 15.0.2, 16.0.0, 16.1.0, 17.0.0)
# ERROR: No matching distribution found for pyarrow==0.14.1
# Requirement already satisfied: pandas in /Users/stevenogwal/development/ml_eng/.venv/lib/python3.11/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /Users/stevenogwal/development/ml_eng/.venv/lib/python3.11/site-packages (from pandas) (2.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/stevenogwal/development/ml_eng/.venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/stevenogwal/development/ml_eng/.venv/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/stevenogwal/development/ml_eng/.venv/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /Users/stevenogwal/development/ml_eng/.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Collecting numpy==1.19.5
#   Downloading numpy-1.19.5.zip (7.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 5.5 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: numpy
#   Building wheel for numpy (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Building wheel for numpy (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [895 lines of output]
#       setup.py:67: RuntimeWarning: NumPy 1.19.5 may not yet support Python 3.11.
#         warnings.warn(
#       Running from numpy source directory.
#       Cythonizing sources
#       numpy/random/_bounded_integers.pxd.in has not changed
#       numpy/random/_philox.pyx has not changed
#       numpy/random/_bounded_integers.pyx.in has not changed
#       numpy/random/_sfc64.pyx has not changed
#       numpy/random/_mt19937.pyx has not changed
#       numpy/random/bit_generator.pyx has not changed
#       Processing numpy/random/_bounded_integers.pyx
#       numpy/random/mtrand.pyx has not changed
#       numpy/random/_generator.pyx has not changed
#       numpy/random/_pcg64.pyx has not changed
#       numpy/random/_common.pyx has not changed
#       blas_opt_info:
#       blas_mkl_info:
#       customize UnixCCompiler
#         libraries mkl_rt not found in ['/Users/stevenogwal/development/ml_eng/.venv/lib', '/usr/local/lib', '/usr/lib']
#         NOT AVAILABLE
#
#       blis_info:
#         libraries blis not found in ['/Users/stevenogwal/development/ml_eng/.venv/lib', '/usr/local/lib', '/usr/lib']
#         NOT AVAILABLE
#
#       openblas_info:
#         libraries openblas not found in ['/Users/stevenogwal/development/ml_eng/.venv/lib', '/usr/local/lib', '/usr/lib']
#         NOT AVAILABLE
#
#       atlas_3_10_blas_threads_info:
#       Setting PTATLAS=ATLAS
#         libraries tatlas not found in ['/Users/stevenogwal/development/ml_eng/.venv/lib', '/usr/local/lib', '/usr/lib']
#         NOT AVAILABLE
#
#       atlas_3_10_blas_info:
#         libraries satlas not found in ['/Users/stevenogwal/development/ml_eng/.venv/lib', '/usr/local/lib', '/usr/lib']
#         NOT AVAILABLE
#
#       atlas_blas_threads_info:
#       Setting PTATLAS=ATLAS
#         libraries ptf77blas,ptcblas,atlas not found in ['/Users/stevenogwal/development/ml_eng/.venv/lib', '/usr/local/lib', '/usr/lib']
#         NOT AVAILABLE
#
#       atlas_blas_info:
#         libraries f77blas,cblas,atlas not found in ['/Users/stevenogwal/development/ml_eng/.venv/lib', '/usr/local/lib', '/usr/lib']
#         NOT AVAILABLE
#
#       accelerate_info:
#         libraries accelerate not found in ['/Users/stevenogwal/development/ml_eng/.venv/lib', '/usr/local/lib', '/usr/lib']
#       Library accelerate was not found. Ignoring
#         libraries veclib not found in ['/Users/stevenogwal/development/ml_eng/.venv/lib', '/usr/local/lib', '/usr/lib']
#       Library veclib was not found. Ignoring
#         FOUND:
#           extra_compile_args = ['-faltivec', '-I/System/Library/Frameworks/vecLib.framework/Headers']
#           extra_link_args = ['-Wl,-framework', '-Wl,Accelerate']
#           define_macros = [('NO_ATLAS_INFO', 3), ('HAVE_CBLAS', None)]
#
#         FOUND:
#           extra_compile_args = ['-faltivec', '-I/System/Library/Frameworks/vecLib.framework/Headers']
#           extra_link_args = ['-Wl,-framework', '-Wl,Accelerate']
#           define_macros = [('NO_ATLAS_INFO', 3), ('HAVE_CBLAS', None)]
#
#       non-existing path in 'numpy/distutils': 'site.cfg'
#       lapack_opt_info:
#       lapack_mkl_info:
#         libraries mkl_rt not found in ['/Users/stevenogwal/development/ml_eng/.venv/lib', '/usr/local/lib', '/usr/lib']
#         NOT AVAILABLE
#
#       openblas_lapack_info:
#         libraries openblas not found in ['/Users/stevenogwal/development/ml_eng/.venv/lib', '/usr/local/lib', '/usr/lib']
#         NOT AVAILABLE
#
#       openblas_clapack_info:
#         libraries openblas,lapack not found in ['/Users/stevenogwal/development/ml_eng/.venv/lib', '/usr/local/lib', '/usr/lib']
#         NOT AVAILABLE
#
#       flame_info:
#         libraries flame not found in ['/Users/stevenogwal/development/ml_eng/.venv/lib', '/usr/local/lib', '/usr/lib']
#         NOT AVAILABLE
#
#       atlas_3_10_threads_info:
#       Setting PTATLAS=ATLAS
#         libraries lapack_atlas not found in /Users/stevenogwal/development/ml_eng/.venv/lib
#         libraries tatlas,tatlas not found in /Users/stevenogwal/development/ml_eng/.venv/lib
#         libraries lapack_atlas not found in /usr/local/lib
#         libraries tatlas,tatlas not found in /usr/local/lib
#         libraries lapack_atlas not found in /usr/lib
#         libraries tatlas,tatlas not found in /usr/lib
#       <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#         NOT AVAILABLE
#
#       atlas_3_10_info:
#         libraries lapack_atlas not found in /Users/stevenogwal/development/ml_eng/.venv/lib
#         libraries satlas,satlas not found in /Users/stevenogwal/development/ml_eng/.venv/lib
#         libraries lapack_atlas not found in /usr/local/lib
#         libraries satlas,satlas not found in /usr/local/lib
#         libraries lapack_atlas not found in /usr/lib
#         libraries satlas,satlas not found in /usr/lib
#       <class 'numpy.distutils.system_info.atlas_3_10_info'>
#         NOT AVAILABLE
#
#       atlas_threads_info:
#       Setting PTATLAS=ATLAS
#         libraries lapack_atlas not found in /Users/stevenogwal/development/ml_eng/.venv/lib
#         libraries ptf77blas,ptcblas,atlas not found in /Users/stevenogwal/development/ml_eng/.venv/lib
#         libraries lapack_atlas not found in /usr/local/lib
#         libraries ptf77blas,ptcblas,atlas not found in /usr/local/lib
#         libraries lapack_atlas not found in /usr/lib
#         libraries ptf77blas,ptcblas,atlas not found in /usr/lib
#       <class 'numpy.distutils.system_info.atlas_threads_info'>
#         NOT AVAILABLE
#
#       atlas_info:
#         libraries lapack_atlas not found in /Users/stevenogwal/development/ml_eng/.venv/lib
#         libraries f77blas,cblas,atlas not found in /Users/stevenogwal/development/ml_eng/.venv/lib
#         libraries lapack_atlas not found in /usr/local/lib
#         libraries f77blas,cblas,atlas not found in /usr/local/lib
#         libraries lapack_atlas not found in /usr/lib
#         libraries f77blas,cblas,atlas not found in /usr/lib
#       <class 'numpy.distutils.system_info.atlas_info'>
#         NOT AVAILABLE
#
#         FOUND:
#           extra_compile_args = ['-faltivec', '-I/System/Library/Frameworks/vecLib.framework/Headers']
#           extra_link_args = ['-Wl,-framework', '-Wl,Accelerate']
#           define_macros = [('NO_ATLAS_INFO', 3), ('HAVE_CBLAS', None)]
#
#       /private/var/folders/ws/c9l_s4sn6bgdlfczk2h4scbr0000gn/T/pip-build-env-j4_oftl4/overlay/lib/python3.11/site-packages/setuptools/_distutils/dist.py:275: UserWarning: Unknown distribution option: 'define_macros'
#         warnings.warn(msg)
#       running bdist_wheel
#       running build
#       running config_cc
#       unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#       running config_fc
#       unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#       running build_src
#       build_src
#       building py_modules sources
#       building library "npymath" sources
#       Could not locate executable gfortran
#       Could not locate executable f95
#       Could not locate executable f90
#       Could not locate executable f77
#       Could not locate executable xlf90
#       Could not locate executable xlf
#       Could not locate executable ifort
#       Could not locate executable ifc
#       Could not locate executable g77
#       Could not locate executable g95
#       Could not locate executable pgfortran
#       don't know how to compile Fortran code on platform 'posix'
#         adding 'build/src.macosx-13.0-arm64-3.11/numpy/core/src/npymath' to include_dirs.
#       None - nothing done with h_files = ['build/src.macosx-13.0-arm64-3.11/numpy/core/src/npymath/npy_math_internal.h']
#       building library "npysort" sources
#         adding 'build/src.macosx-13.0-arm64-3.11/numpy/core/src/common' to include_dirs.
#       None - nothing done with h_files = ['build/src.macosx-13.0-arm64-3.11/numpy/core/src/common/npy_sort.h', 'build/src.macosx-13.0-arm64-3.11/numpy/core/src/common/npy_partition.h', 'build/src.macosx-13.0-arm64-3.11/numpy/core/src/common/npy_binsearch.h']
#       building library "npyrandom" sources
#       building extension "numpy.core._multiarray_tests" sources
#       building extension "numpy.core._multiarray_umath" sources
#         adding 'build/src.macosx-13.0-arm64-3.11/numpy/core/src/umath' to include_dirs.
#         adding 'build/src.macosx-13.0-arm64-3.11/numpy/core/src/npymath' to include_dirs.
#         adding 'build/src.macosx-13.0-arm64-3.11/numpy/core/src/common' to include_dirs.
#       numpy.core - nothing done with h_files = ['build/src.macosx-13.0-arm64-3.11/numpy/core/src/umath/funcs.inc', 'build/src.macosx-13.0-arm64-3.11/numpy/core/src/umath/simd.inc', 'build/src.macosx-13.0-arm64-3.11/numpy/core/src/umath/loops.h', 'build/src.macosx-13.0-arm64-3.11/numpy/core/src/umath/matmul.h', 'build/src.macosx-13.0-arm64-3.11/numpy/core/src/umath/clip.h', 'build/src.macosx-13.0-arm64-3.11/numpy/core/src/npymath/npy_math_internal.h', 'build/src.macosx-13.0-arm64-3.11/numpy/core/src/common/templ_common.h', 'build/src.macosx-13.0-arm64-3.11/numpy/core/include/numpy/config.h', 'build/src.macosx-13.0-arm64-3.11/numpy/core/include/numpy/_numpyconfig.h', 'build/src.macosx-13.0-arm64-3.11/numpy/core/include/numpy/__multiarray_api.h', 'build/src.macosx-13.0-arm64-3.11/numpy/core/include/numpy/__ufunc_api.h']
#       building extension "numpy.core._umath_tests" sources
#       building extension "numpy.core._rational_tests" sources
#       building extension "numpy.core._struct_ufunc_tests" sources
#       building extension "numpy.core._operand_flag_tests" sources
#       building extension "numpy.fft._pocketfft_internal" sources
#       building extension "numpy.linalg.lapack_lite" sources
#       building extension "numpy.linalg._umath_linalg" sources
#       building extension "numpy.random._mt19937" sources
#       building extension "numpy.random._philox" sources
#       building extension "numpy.random._pcg64" sources
#       building extension "numpy.random._sfc64" sources
#       building extension "numpy.random._common" sources
#       building extension "numpy.random.bit_generator" sources
#       building extension "numpy.random._generator" sources
#       building extension "numpy.random._bounded_integers" sources
#       building extension "numpy.random.mtrand" sources
#       building data_files sources
#       build_src: building npy-pkg config files
#       running build_py
#       creating build/lib.macosx-13.0-arm64-3.11
#       creating build/lib.macosx-13.0-arm64-3.11/numpy
#       copying numpy/conftest.py -> build/lib.macosx-13.0-arm64-3.11/numpy
#       copying numpy/version.py -> build/lib.macosx-13.0-arm64-3.11/numpy
#       copying numpy/_globals.py -> build/lib.macosx-13.0-arm64-3.11/numpy
#       copying numpy/__init__.py -> build/lib.macosx-13.0-arm64-3.11/numpy
#       copying numpy/dual.py -> build/lib.macosx-13.0-arm64-3.11/numpy
#       copying numpy/_distributor_init.py -> build/lib.macosx-13.0-arm64-3.11/numpy
#       copying numpy/setup.py -> build/lib.macosx-13.0-arm64-3.11/numpy
#       copying numpy/ctypeslib.py -> build/lib.macosx-13.0-arm64-3.11/numpy
#       copying numpy/matlib.py -> build/lib.macosx-13.0-arm64-3.11/numpy
#       copying numpy/_pytesttester.py -> build/lib.macosx-13.0-arm64-3.11/numpy
#       copying build/src.macosx-13.0-arm64-3.11/numpy/__config__.py -> build/lib.macosx-13.0-arm64-3.11/numpy
#       creating build/lib.macosx-13.0-arm64-3.11/numpy/compat
#       copying numpy/compat/py3k.py -> build/lib.macosx-13.0-arm64-3.11/numpy/compat
#       copying numpy/compat/__init__.py -> build/lib.macosx-13.0-arm64-3.11/numpy/compat
#       copying numpy/compat/setup.py -> build/lib.macosx-13.0-arm64-3.11/numpy/compat
#       copying numpy/compat/_inspect.py -> build/lib.macosx-13.0-arm64-3.11/numpy/compat
#       creating build/lib.macosx-13.0-arm64-3.11/numpy/compat/tests
#       copying numpy/compat/tests/__init__.py -> build/lib.macosx-13.0-arm64-3.11/numpy/compat/tests
#       copying numpy/compat/tests/test_compat.py -> build/lib.macosx-13.0-arm64-3.11/numpy/compat/tests
#       creating build/lib.macosx-13.0-arm64-3.11/numpy/core
#       copying numpy/core/umath.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core
#       copying numpy/core/fromnumeric.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core
#       copying numpy/core/_dtype.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core
#       copying numpy/core/_add_newdocs.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core
#       copying numpy/core/_methods.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core
#       copying numpy/core/_internal.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core
#       copying numpy/core/_string_helpers.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core
#       copying numpy/core/multiarray.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core
#       copying numpy/core/_asarray.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core
#       copying numpy/core/records.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core
#       copying numpy/core/__init__.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core
#       copying numpy/core/setup_common.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core
#       copying numpy/core/memmap.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core
#       copying numpy/core/overrides.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core
#       copying numpy/core/getlimits.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core
#       copying numpy/core/_dtype_ctypes.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core
#       copying numpy/core/defchararray.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core
#       copying numpy/core/shape_base.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core
#       copying numpy/core/machar.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core
#       copying numpy/core/setup.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core
#       copying numpy/core/numeric.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core
#       copying numpy/core/function_base.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core
#       copying numpy/core/einsumfunc.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core
#       copying numpy/core/umath_tests.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core
#       copying numpy/core/_ufunc_config.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core
#       copying numpy/core/_exceptions.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core
#       copying numpy/core/numerictypes.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core
#       copying numpy/core/_type_aliases.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core
#       copying numpy/core/cversions.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core
#       copying numpy/core/arrayprint.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core
#       copying numpy/core/code_generators/generate_numpy_api.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core
#       creating build/lib.macosx-13.0-arm64-3.11/numpy/core/tests
#       copying numpy/core/tests/test_numerictypes.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core/tests
#       copying numpy/core/tests/test_scalar_methods.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core/tests
#       copying numpy/core/tests/test_scalarmath.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core/tests
#       copying numpy/core/tests/test_item_selection.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core/tests
#       copying numpy/core/tests/test_machar.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core/tests
#       copying numpy/core/tests/test_unicode.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core/tests
#       copying numpy/core/tests/test_arrayprint.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core/tests
#       copying numpy/core/tests/test_scalarbuffer.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core/tests
#       copying numpy/core/tests/test_indexerrors.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core/tests
#       copying numpy/core/tests/test_print.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core/tests
#       copying numpy/core/tests/test_half.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core/tests
#       copying numpy/core/tests/test_mem_overlap.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core/tests
#       copying numpy/core/tests/test_shape_base.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core/tests
#       copying numpy/core/tests/test_deprecations.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core/tests
#       copying numpy/core/tests/__init__.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core/tests
#       copying numpy/core/tests/test_errstate.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core/tests
#       copying numpy/core/tests/test_records.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core/tests
#       copying numpy/core/tests/test_scalarinherit.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core/tests
#       copying numpy/core/tests/test_indexing.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core/tests
#       copying numpy/core/tests/test_umath.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core/tests
#       copying numpy/core/tests/test_numeric.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core/tests
#       copying numpy/core/tests/test_function_base.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core/tests
#       copying numpy/core/tests/test_datetime.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core/tests
#       copying numpy/core/tests/test__exceptions.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core/tests
#       copying numpy/core/tests/test_extint128.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core/tests
#       copying numpy/core/tests/test_umath_complex.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core/tests
#       copying numpy/core/tests/_locales.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core/tests
#       copying numpy/core/tests/test_defchararray.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core/tests
#       copying numpy/core/tests/test_conversion_utils.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core/tests
#       copying numpy/core/tests/test_scalarprint.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core/tests
#       copying numpy/core/tests/test_abc.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core/tests
#       copying numpy/core/tests/test_ufunc.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core/tests
#       copying numpy/core/tests/test_dtype.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core/tests
#       copying numpy/core/tests/test_umath_accuracy.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core/tests
#       copying numpy/core/tests/test_getlimits.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core/tests
#       copying numpy/core/tests/test_einsum.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core/tests
#       copying numpy/core/tests/test_api.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core/tests
#       copying numpy/core/tests/test_longdouble.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core/tests
#       copying numpy/core/tests/test_overrides.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core/tests
#       copying numpy/core/tests/test_scalar_ctors.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core/tests
#       copying numpy/core/tests/test_multiarray.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core/tests
#       copying numpy/core/tests/test_memmap.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core/tests
#       copying numpy/core/tests/test_nditer.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core/tests
#       copying numpy/core/tests/test_cpu_features.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core/tests
#       copying numpy/core/tests/test_protocols.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core/tests
#       copying numpy/core/tests/test_regression.py -> build/lib.macosx-13.0-arm64-3.11/numpy/core/tests
#       creating build/lib.macosx-13.0-arm64-3.11/numpy/distutils
#       copying numpy/distutils/unixccompiler.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils
#       copying numpy/distutils/numpy_distribution.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils
#       copying numpy/distutils/conv_template.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils
#       copying numpy/distutils/cpuinfo.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils
#       copying numpy/distutils/ccompiler.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils
#       copying numpy/distutils/msvc9compiler.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils
#       copying numpy/distutils/npy_pkg_config.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils
#       copying numpy/distutils/misc_util.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils
#       copying numpy/distutils/log.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils
#       copying numpy/distutils/line_endings.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils
#       copying numpy/distutils/lib2def.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils
#       copying numpy/distutils/pathccompiler.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils
#       copying numpy/distutils/system_info.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils
#       copying numpy/distutils/__init__.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils
#       copying numpy/distutils/core.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils
#       copying numpy/distutils/exec_command.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils
#       copying numpy/distutils/from_template.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils
#       copying numpy/distutils/mingw32ccompiler.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils
#       copying numpy/distutils/setup.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils
#       copying numpy/distutils/extension.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils
#       copying numpy/distutils/msvccompiler.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils
#       copying numpy/distutils/intelccompiler.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils
#       copying numpy/distutils/_shell_utils.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils
#       copying build/src.macosx-13.0-arm64-3.11/numpy/distutils/__config__.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils
#       creating build/lib.macosx-13.0-arm64-3.11/numpy/distutils/command
#       copying numpy/distutils/command/build.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils/command
#       copying numpy/distutils/command/config_compiler.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils/command
#       copying numpy/distutils/command/build_ext.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils/command
#       copying numpy/distutils/command/config.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils/command
#       copying numpy/distutils/command/install_headers.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils/command
#       copying numpy/distutils/command/build_py.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils/command
#       copying numpy/distutils/command/build_src.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils/command
#       copying numpy/distutils/command/__init__.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils/command
#       copying numpy/distutils/command/sdist.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils/command
#       copying numpy/distutils/command/build_scripts.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils/command
#       copying numpy/distutils/command/bdist_rpm.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils/command
#       copying numpy/distutils/command/install_clib.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils/command
#       copying numpy/distutils/command/build_clib.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils/command
#       copying numpy/distutils/command/autodist.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils/command
#       copying numpy/distutils/command/egg_info.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils/command
#       copying numpy/distutils/command/install.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils/command
#       copying numpy/distutils/command/develop.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils/command
#       copying numpy/distutils/command/install_data.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils/command
#       creating build/lib.macosx-13.0-arm64-3.11/numpy/distutils/fcompiler
#       copying numpy/distutils/fcompiler/gnu.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils/fcompiler
#       copying numpy/distutils/fcompiler/compaq.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils/fcompiler
#       copying numpy/distutils/fcompiler/intel.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils/fcompiler
#       copying numpy/distutils/fcompiler/none.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils/fcompiler
#       copying numpy/distutils/fcompiler/nag.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils/fcompiler
#       copying numpy/distutils/fcompiler/pg.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils/fcompiler
#       copying numpy/distutils/fcompiler/ibm.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils/fcompiler
#       copying numpy/distutils/fcompiler/sun.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils/fcompiler
#       copying numpy/distutils/fcompiler/nv.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils/fcompiler
#       copying numpy/distutils/fcompiler/lahey.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils/fcompiler
#       copying numpy/distutils/fcompiler/__init__.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils/fcompiler
#       copying numpy/distutils/fcompiler/g95.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils/fcompiler
#       copying numpy/distutils/fcompiler/mips.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils/fcompiler
#       copying numpy/distutils/fcompiler/hpux.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils/fcompiler
#       copying numpy/distutils/fcompiler/environment.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils/fcompiler
#       copying numpy/distutils/fcompiler/pathf95.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils/fcompiler
#       copying numpy/distutils/fcompiler/absoft.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils/fcompiler
#       copying numpy/distutils/fcompiler/vast.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils/fcompiler
#       creating build/lib.macosx-13.0-arm64-3.11/numpy/distutils/tests
#       copying numpy/distutils/tests/test_system_info.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils/tests
#       copying numpy/distutils/tests/test_mingw32ccompiler.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils/tests
#       copying numpy/distutils/tests/test_from_template.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils/tests
#       copying numpy/distutils/tests/__init__.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils/tests
#       copying numpy/distutils/tests/test_fcompiler_intel.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils/tests
#       copying numpy/distutils/tests/test_misc_util.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils/tests
#       copying numpy/distutils/tests/test_fcompiler.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils/tests
#       copying numpy/distutils/tests/test_shell_utils.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils/tests
#       copying numpy/distutils/tests/test_exec_command.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils/tests
#       copying numpy/distutils/tests/test_npy_pkg_config.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils/tests
#       copying numpy/distutils/tests/test_fcompiler_nagfor.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils/tests
#       copying numpy/distutils/tests/test_fcompiler_gnu.py -> build/lib.macosx-13.0-arm64-3.11/numpy/distutils/tests
#       creating build/lib.macosx-13.0-arm64-3.11/numpy/doc
#       copying numpy/doc/misc.py -> build/lib.macosx-13.0-arm64-3.11/numpy/doc
#       copying numpy/doc/internals.py -> build/lib.macosx-13.0-arm64-3.11/numpy/doc
#       copying numpy/doc/creation.py -> build/lib.macosx-13.0-arm64-3.11/numpy/doc
#       copying numpy/doc/dispatch.py -> build/lib.macosx-13.0-arm64-3.11/numpy/doc
#       copying numpy/doc/constants.py -> build/lib.macosx-13.0-arm64-3.11/numpy/doc
#       copying numpy/doc/ufuncs.py -> build/lib.macosx-13.0-arm64-3.11/numpy/doc
#       copying numpy/doc/__init__.py -> build/lib.macosx-13.0-arm64-3.11/numpy/doc
#       copying numpy/doc/broadcasting.py -> build/lib.macosx-13.0-arm64-3.11/numpy/doc
#       copying numpy/doc/basics.py -> build/lib.macosx-13.0-arm64-3.11/numpy/doc
#       copying numpy/doc/subclassing.py -> build/lib.macosx-13.0-arm64-3.11/numpy/doc
#       copying numpy/doc/indexing.py -> build/lib.macosx-13.0-arm64-3.11/numpy/doc
#       copying numpy/doc/byteswapping.py -> build/lib.macosx-13.0-arm64-3.11/numpy/doc
#       copying numpy/doc/structured_arrays.py -> build/lib.macosx-13.0-arm64-3.11/numpy/doc
#       copying numpy/doc/glossary.py -> build/lib.macosx-13.0-arm64-3.11/numpy/doc
#       creating build/lib.macosx-13.0-arm64-3.11/numpy/f2py
#       copying numpy/f2py/cfuncs.py -> build/lib.macosx-13.0-arm64-3.11/numpy/f2py
#       copying numpy/f2py/common_rules.py -> build/lib.macosx-13.0-arm64-3.11/numpy/f2py
#       copying numpy/f2py/crackfortran.py -> build/lib.macosx-13.0-arm64-3.11/numpy/f2py
#       copying numpy/f2py/cb_rules.py -> build/lib.macosx-13.0-arm64-3.11/numpy/f2py
#       copying numpy/f2py/__init__.py -> build/lib.macosx-13.0-arm64-3.11/numpy/f2py
#       copying numpy/f2py/rules.py -> build/lib.macosx-13.0-arm64-3.11/numpy/f2py
#       copying numpy/f2py/f2py2e.py -> build/lib.macosx-13.0-arm64-3.11/numpy/f2py
#       copying numpy/f2py/func2subr.py -> build/lib.macosx-13.0-arm64-3.11/numpy/f2py
#       copying numpy/f2py/__version__.py -> build/lib.macosx-13.0-arm64-3.11/numpy/f2py
#       copying numpy/f2py/diagnose.py -> build/lib.macosx-13.0-arm64-3.11/numpy/f2py
#       copying numpy/f2py/setup.py -> build/lib.macosx-13.0-arm64-3.11/numpy/f2py
#       copying numpy/f2py/capi_maps.py -> build/lib.macosx-13.0-arm64-3.11/numpy/f2py
#       copying numpy/f2py/f90mod_rules.py -> build/lib.macosx-13.0-arm64-3.11/numpy/f2py
#       copying numpy/f2py/f2py_testing.py -> build/lib.macosx-13.0-arm64-3.11/numpy/f2py
#       copying numpy/f2py/use_rules.py -> build/lib.macosx-13.0-arm64-3.11/numpy/f2py
#       copying numpy/f2py/auxfuncs.py -> build/lib.macosx-13.0-arm64-3.11/numpy/f2py
#       copying numpy/f2py/__main__.py -> build/lib.macosx-13.0-arm64-3.11/numpy/f2py
#       creating build/lib.macosx-13.0-arm64-3.11/numpy/f2py/tests
#       copying numpy/f2py/tests/test_mixed.py -> build/lib.macosx-13.0-arm64-3.11/numpy/f2py/tests
#       copying numpy/f2py/tests/test_return_logical.py -> build/lib.macosx-13.0-arm64-3.11/numpy/f2py/tests
#       copying numpy/f2py/tests/test_assumed_shape.py -> build/lib.macosx-13.0-arm64-3.11/numpy/f2py/tests
#       copying numpy/f2py/tests/test_common.py -> build/lib.macosx-13.0-arm64-3.11/numpy/f2py/tests
#       copying numpy/f2py/tests/test_kind.py -> build/lib.macosx-13.0-arm64-3.11/numpy/f2py/tests
#       copying numpy/f2py/tests/test_array_from_pyobj.py -> build/lib.macosx-13.0-arm64-3.11/numpy/f2py/tests
#       copying numpy/f2py/tests/test_return_real.py -> build/lib.macosx-13.0-arm64-3.11/numpy/f2py/tests
#       copying numpy/f2py/tests/util.py -> build/lib.macosx-13.0-arm64-3.11/numpy/f2py/tests
#       copying numpy/f2py/tests/test_size.py -> build/lib.macosx-13.0-arm64-3.11/numpy/f2py/tests
#       copying numpy/f2py/tests/test_callback.py -> build/lib.macosx-13.0-arm64-3.11/numpy/f2py/tests
#       copying numpy/f2py/tests/test_string.py -> build/lib.macosx-13.0-arm64-3.11/numpy/f2py/tests
#       copying numpy/f2py/tests/__init__.py -> build/lib.macosx-13.0-arm64-3.11/numpy/f2py/tests
#       copying numpy/f2py/tests/test_quoted_character.py -> build/lib.macosx-13.0-arm64-3.11/numpy/f2py/tests
#       copying numpy/f2py/tests/test_parameter.py -> build/lib.macosx-13.0-arm64-3.11/numpy/f2py/tests
#       copying numpy/f2py/tests/test_semicolon_split.py -> build/lib.macosx-13.0-arm64-3.11/numpy/f2py/tests
#       copying numpy/f2py/tests/test_compile_function.py -> build/lib.macosx-13.0-arm64-3.11/numpy/f2py/tests
#       copying numpy/f2py/tests/test_block_docstring.py -> build/lib.macosx-13.0-arm64-3.11/numpy/f2py/tests
#       copying numpy/f2py/tests/test_return_integer.py -> build/lib.macosx-13.0-arm64-3.11/numpy/f2py/tests
#       copying numpy/f2py/tests/test_return_character.py -> build/lib.macosx-13.0-arm64-3.11/numpy/f2py/tests
#       copying numpy/f2py/tests/test_return_complex.py -> build/lib.macosx-13.0-arm64-3.11/numpy/f2py/tests
#       copying numpy/f2py/tests/test_crackfortran.py -> build/lib.macosx-13.0-arm64-3.11/numpy/f2py/tests
#       copying numpy/f2py/tests/test_regression.py -> build/lib.macosx-13.0-arm64-3.11/numpy/f2py/tests
#       creating build/lib.macosx-13.0-arm64-3.11/numpy/fft
#       copying numpy/fft/__init__.py -> build/lib.macosx-13.0-arm64-3.11/numpy/fft
#       copying numpy/fft/setup.py -> build/lib.macosx-13.0-arm64-3.11/numpy/fft
#       copying numpy/fft/helper.py -> build/lib.macosx-13.0-arm64-3.11/numpy/fft
#       copying numpy/fft/_pocketfft.py -> build/lib.macosx-13.0-arm64-3.11/numpy/fft
#       creating build/lib.macosx-13.0-arm64-3.11/numpy/fft/tests
#       copying numpy/fft/tests/test_pocketfft.py -> build/lib.macosx-13.0-arm64-3.11/numpy/fft/tests
#       copying numpy/fft/tests/test_helper.py -> build/lib.macosx-13.0-arm64-3.11/numpy/fft/tests
#       copying numpy/fft/tests/__init__.py -> build/lib.macosx-13.0-arm64-3.11/numpy/fft/tests
#       creating build/lib.macosx-13.0-arm64-3.11/numpy/lib
#       copying numpy/lib/_iotools.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib
#       copying numpy/lib/mixins.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib
#       copying numpy/lib/nanfunctions.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib
#       copying numpy/lib/recfunctions.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib
#       copying numpy/lib/histograms.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib
#       copying numpy/lib/scimath.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib
#       copying numpy/lib/_version.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib
#       copying numpy/lib/user_array.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib
#       copying numpy/lib/__init__.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib
#       copying numpy/lib/format.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib
#       copying numpy/lib/twodim_base.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib
#       copying numpy/lib/financial.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib
#       copying numpy/lib/index_tricks.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib
#       copying numpy/lib/npyio.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib
#       copying numpy/lib/shape_base.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib
#       copying numpy/lib/setup.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib
#       copying numpy/lib/stride_tricks.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib
#       copying numpy/lib/utils.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib
#       copying numpy/lib/arrayterator.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib
#       copying numpy/lib/function_base.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib
#       copying numpy/lib/arraysetops.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib
#       copying numpy/lib/arraypad.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib
#       copying numpy/lib/type_check.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib
#       copying numpy/lib/polynomial.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib
#       copying numpy/lib/_datasource.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib
#       copying numpy/lib/ufunclike.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib
#       creating build/lib.macosx-13.0-arm64-3.11/numpy/lib/tests
#       copying numpy/lib/tests/test_type_check.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib/tests
#       copying numpy/lib/tests/test_utils.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib/tests
#       copying numpy/lib/tests/test_twodim_base.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib/tests
#       copying numpy/lib/tests/test_polynomial.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib/tests
#       copying numpy/lib/tests/test__iotools.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib/tests
#       copying numpy/lib/tests/test_shape_base.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib/tests
#       copying numpy/lib/tests/test_ufunclike.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib/tests
#       copying numpy/lib/tests/test_index_tricks.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib/tests
#       copying numpy/lib/tests/__init__.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib/tests
#       copying numpy/lib/tests/test_arrayterator.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib/tests
#       copying numpy/lib/tests/test__version.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib/tests
#       copying numpy/lib/tests/test_io.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib/tests
#       copying numpy/lib/tests/test_arraysetops.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib/tests
#       copying numpy/lib/tests/test_function_base.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib/tests
#       copying numpy/lib/tests/test_arraypad.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib/tests
#       copying numpy/lib/tests/test_mixins.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib/tests
#       copying numpy/lib/tests/test_packbits.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib/tests
#       copying numpy/lib/tests/test__datasource.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib/tests
#       copying numpy/lib/tests/test_stride_tricks.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib/tests
#       copying numpy/lib/tests/test_financial.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib/tests
#       copying numpy/lib/tests/test_recfunctions.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib/tests
#       copying numpy/lib/tests/test_nanfunctions.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib/tests
#       copying numpy/lib/tests/test_format.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib/tests
#       copying numpy/lib/tests/test_histograms.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib/tests
#       copying numpy/lib/tests/test_regression.py -> build/lib.macosx-13.0-arm64-3.11/numpy/lib/tests
#       creating build/lib.macosx-13.0-arm64-3.11/numpy/linalg
#       copying numpy/linalg/__init__.py -> build/lib.macosx-13.0-arm64-3.11/numpy/linalg
#       copying numpy/linalg/setup.py -> build/lib.macosx-13.0-arm64-3.11/numpy/linalg
#       copying numpy/linalg/linalg.py -> build/lib.macosx-13.0-arm64-3.11/numpy/linalg
#       creating build/lib.macosx-13.0-arm64-3.11/numpy/linalg/tests
#       copying numpy/linalg/tests/test_linalg.py -> build/lib.macosx-13.0-arm64-3.11/numpy/linalg/tests
#       copying numpy/linalg/tests/test_deprecations.py -> build/lib.macosx-13.0-arm64-3.11/numpy/linalg/tests
#       copying numpy/linalg/tests/__init__.py -> build/lib.macosx-13.0-arm64-3.11/numpy/linalg/tests
#       copying numpy/linalg/tests/test_build.py -> build/lib.macosx-13.0-arm64-3.11/numpy/linalg/tests
#       copying numpy/linalg/tests/test_regression.py -> build/lib.macosx-13.0-arm64-3.11/numpy/linalg/tests
#       creating build/lib.macosx-13.0-arm64-3.11/numpy/ma
#       copying numpy/ma/extras.py -> build/lib.macosx-13.0-arm64-3.11/numpy/ma
#       copying numpy/ma/testutils.py -> build/lib.macosx-13.0-arm64-3.11/numpy/ma
#       copying numpy/ma/__init__.py -> build/lib.macosx-13.0-arm64-3.11/numpy/ma
#       copying numpy/ma/core.py -> build/lib.macosx-13.0-arm64-3.11/numpy/ma
#       copying numpy/ma/bench.py -> build/lib.macosx-13.0-arm64-3.11/numpy/ma
#       copying numpy/ma/setup.py -> build/lib.macosx-13.0-arm64-3.11/numpy/ma
#       copying numpy/ma/timer_comparison.py -> build/lib.macosx-13.0-arm64-3.11/numpy/ma
#       copying numpy/ma/mrecords.py -> build/lib.macosx-13.0-arm64-3.11/numpy/ma
#       creating build/lib.macosx-13.0-arm64-3.11/numpy/ma/tests
#       copying numpy/ma/tests/test_old_ma.py -> build/lib.macosx-13.0-arm64-3.11/numpy/ma/tests
#       copying numpy/ma/tests/test_core.py -> build/lib.macosx-13.0-arm64-3.11/numpy/ma/tests
#       copying numpy/ma/tests/test_deprecations.py -> build/lib.macosx-13.0-arm64-3.11/numpy/ma/tests
#       copying numpy/ma/tests/__init__.py -> build/lib.macosx-13.0-arm64-3.11/numpy/ma/tests
#       copying numpy/ma/tests/test_subclassing.py -> build/lib.macosx-13.0-arm64-3.11/numpy/ma/tests
#       copying numpy/ma/tests/test_extras.py -> build/lib.macosx-13.0-arm64-3.11/numpy/ma/tests
#       copying numpy/ma/tests/test_mrecords.py -> build/lib.macosx-13.0-arm64-3.11/numpy/ma/tests
#       copying numpy/ma/tests/test_regression.py -> build/lib.macosx-13.0-arm64-3.11/numpy/ma/tests
#       creating build/lib.macosx-13.0-arm64-3.11/numpy/matrixlib
#       copying numpy/matrixlib/__init__.py -> build/lib.macosx-13.0-arm64-3.11/numpy/matrixlib
#       copying numpy/matrixlib/setup.py -> build/lib.macosx-13.0-arm64-3.11/numpy/matrixlib
#       copying numpy/matrixlib/defmatrix.py -> build/lib.macosx-13.0-arm64-3.11/numpy/matrixlib
#       creating build/lib.macosx-13.0-arm64-3.11/numpy/matrixlib/tests
#       copying numpy/matrixlib/tests/test_matrix_linalg.py -> build/lib.macosx-13.0-arm64-3.11/numpy/matrixlib/tests
#       copying numpy/matrixlib/tests/test_defmatrix.py -> build/lib.macosx-13.0-arm64-3.11/numpy/matrixlib/tests
#       copying numpy/matrixlib/tests/__init__.py -> build/lib.macosx-13.0-arm64-3.11/numpy/matrixlib/tests
#       copying numpy/matrixlib/tests/test_interaction.py -> build/lib.macosx-13.0-arm64-3.11/numpy/matrixlib/tests
#       copying numpy/matrixlib/tests/test_numeric.py -> build/lib.macosx-13.0-arm64-3.11/numpy/matrixlib/tests
#       copying numpy/matrixlib/tests/test_masked_matrix.py -> build/lib.macosx-13.0-arm64-3.11/numpy/matrixlib/tests
#       copying numpy/matrixlib/tests/test_multiarray.py -> build/lib.macosx-13.0-arm64-3.11/numpy/matrixlib/tests
#       copying numpy/matrixlib/tests/test_regression.py -> build/lib.macosx-13.0-arm64-3.11/numpy/matrixlib/tests
#       creating build/lib.macosx-13.0-arm64-3.11/numpy/polynomial
#       copying numpy/polynomial/laguerre.py -> build/lib.macosx-13.0-arm64-3.11/numpy/polynomial
#       copying numpy/polynomial/_polybase.py -> build/lib.macosx-13.0-arm64-3.11/numpy/polynomial
#       copying numpy/polynomial/polyutils.py -> build/lib.macosx-13.0-arm64-3.11/numpy/polynomial
#       copying numpy/polynomial/__init__.py -> build/lib.macosx-13.0-arm64-3.11/numpy/polynomial
#       copying numpy/polynomial/setup.py -> build/lib.macosx-13.0-arm64-3.11/numpy/polynomial
#       copying numpy/polynomial/hermite_e.py -> build/lib.macosx-13.0-arm64-3.11/numpy/polynomial
#       copying numpy/polynomial/chebyshev.py -> build/lib.macosx-13.0-arm64-3.11/numpy/polynomial
#       copying numpy/polynomial/polynomial.py -> build/lib.macosx-13.0-arm64-3.11/numpy/polynomial
#       copying numpy/polynomial/legendre.py -> build/lib.macosx-13.0-arm64-3.11/numpy/polynomial
#       copying numpy/polynomial/hermite.py -> build/lib.macosx-13.0-arm64-3.11/numpy/polynomial
#       creating build/lib.macosx-13.0-arm64-3.11/numpy/polynomial/tests
#       copying numpy/polynomial/tests/test_chebyshev.py -> build/lib.macosx-13.0-arm64-3.11/numpy/polynomial/tests
#       copying numpy/polynomial/tests/test_hermite_e.py -> build/lib.macosx-13.0-arm64-3.11/numpy/polynomial/tests
#       copying numpy/polynomial/tests/test_polynomial.py -> build/lib.macosx-13.0-arm64-3.11/numpy/polynomial/tests
#       copying numpy/polynomial/tests/__init__.py -> build/lib.macosx-13.0-arm64-3.11/numpy/polynomial/tests
#       copying numpy/polynomial/tests/test_laguerre.py -> build/lib.macosx-13.0-arm64-3.11/numpy/polynomial/tests
#       copying numpy/polynomial/tests/test_legendre.py -> build/lib.macosx-13.0-arm64-3.11/numpy/polynomial/tests
#       copying numpy/polynomial/tests/test_printing.py -> build/lib.macosx-13.0-arm64-3.11/numpy/polynomial/tests
#       copying numpy/polynomial/tests/test_hermite.py -> build/lib.macosx-13.0-arm64-3.11/numpy/polynomial/tests
#       copying numpy/polynomial/tests/test_classes.py -> build/lib.macosx-13.0-arm64-3.11/numpy/polynomial/tests
#       copying numpy/polynomial/tests/test_polyutils.py -> build/lib.macosx-13.0-arm64-3.11/numpy/polynomial/tests
#       creating build/lib.macosx-13.0-arm64-3.11/numpy/random
#       copying numpy/random/_pickle.py -> build/lib.macosx-13.0-arm64-3.11/numpy/random
#       copying numpy/random/__init__.py -> build/lib.macosx-13.0-arm64-3.11/numpy/random
#       copying numpy/random/setup.py -> build/lib.macosx-13.0-arm64-3.11/numpy/random
#       creating build/lib.macosx-13.0-arm64-3.11/numpy/random/tests
#       copying numpy/random/tests/test_generator_mt19937.py -> build/lib.macosx-13.0-arm64-3.11/numpy/random/tests
#       copying numpy/random/tests/test_randomstate.py -> build/lib.macosx-13.0-arm64-3.11/numpy/random/tests
#       copying numpy/random/tests/test_direct.py -> build/lib.macosx-13.0-arm64-3.11/numpy/random/tests
#       copying numpy/random/tests/test_extending.py -> build/lib.macosx-13.0-arm64-3.11/numpy/random/tests
#       copying numpy/random/tests/__init__.py -> build/lib.macosx-13.0-arm64-3.11/numpy/random/tests
#       copying numpy/random/tests/test_smoke.py -> build/lib.macosx-13.0-arm64-3.11/numpy/random/tests
#       copying numpy/random/tests/test_randomstate_regression.py -> build/lib.macosx-13.0-arm64-3.11/numpy/random/tests
#       copying numpy/random/tests/test_seed_sequence.py -> build/lib.macosx-13.0-arm64-3.11/numpy/random/tests
#       copying numpy/random/tests/test_generator_mt19937_regressions.py -> build/lib.macosx-13.0-arm64-3.11/numpy/random/tests
#       copying numpy/random/tests/test_random.py -> build/lib.macosx-13.0-arm64-3.11/numpy/random/tests
#       copying numpy/random/tests/test_regression.py -> build/lib.macosx-13.0-arm64-3.11/numpy/random/tests
#       creating build/lib.macosx-13.0-arm64-3.11/numpy/testing
#       copying numpy/testing/__init__.py -> build/lib.macosx-13.0-arm64-3.11/numpy/testing
# ...
#               npy_intp k;
#               ^~~~~~~~~~~
#       numpy/core/src/npysort/selection.c.src:326:14: note: silence by adding parentheses to mark code as explicitly dead
#           else if (0 && kth == num - 1) {
#                    ^
#                    /* DISABLES CODE */ ( )
#       numpy/core/src/npysort/selection.c.src:328:9: warning: code will never be executed [-Wunreachable-code]
#               npy_intp k;
#               ^~~~~~~~~~~
#       numpy/core/src/npysort/selection.c.src:326:14: note: silence by adding parentheses to mark code as explicitly dead
#           else if (0 && kth == num - 1) {
#                    ^
#                    /* DISABLES CODE */ ( )
#       numpy/core/src/npysort/selection.c.src:328:9: warning: code will never be executed [-Wunreachable-code]
#               npy_intp k;
#               ^~~~~~~~~~~
#       numpy/core/src/npysort/selection.c.src:326:14: note: silence by adding parentheses to mark code as explicitly dead
#           else if (0 && kth == num - 1) {
#                    ^
#                    /* DISABLES CODE */ ( )
#       numpy/core/src/npysort/selection.c.src:328:9: warning: code will never be executed [-Wunreachable-code]
#               npy_intp k;
#               ^~~~~~~~~~~
#       numpy/core/src/npysort/selection.c.src:326:14: note: silence by adding parentheses to mark code as explicitly dead
#           else if (0 && kth == num - 1) {
#                    ^
#                    /* DISABLES CODE */ ( )
#       numpy/core/src/npysort/selection.c.src:328:9: warning: code will never be executed [-Wunreachable-code]
#               npy_intp k;
#               ^~~~~~~~~~~
#       numpy/core/src/npysort/selection.c.src:326:14: note: silence by adding parentheses to mark code as explicitly dead
#           else if (0 && kth == num - 1) {
#                    ^
#                    /* DISABLES CODE */ ( )
#       numpy/core/src/npysort/selection.c.src:328:9: warning: code will never be executed [-Wunreachable-code]
#               npy_intp k;
#               ^~~~~~~~~~~
#       numpy/core/src/npysort/selection.c.src:326:14: note: silence by adding parentheses to mark code as explicitly dead
#           else if (0 && kth == num - 1) {
#                    ^
#                    /* DISABLES CODE */ ( )
#       numpy/core/src/npysort/selection.c.src:328:9: warning: code will never be executed [-Wunreachable-code]
#               npy_intp k;
#               ^~~~~~~~~~~
#       numpy/core/src/npysort/selection.c.src:326:14: note: silence by adding parentheses to mark code as explicitly dead
#           else if (0 && kth == num - 1) {
#                    ^
#                    /* DISABLES CODE */ ( )
#       22 warnings generated.
#       xcrun: adding 7 object files to build/temp.macosx-13.0-arm64-3.11/libnpysort.a
#       ranlib:@ build/temp.macosx-13.0-arm64-3.11/libnpysort.a
#       building 'npyrandom' library
#       compiling C sources
#       C compiler: clang -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -isysroot /Library/Developer/CommandLineTools/SDKs/MacOSX13.sdk
#
#       creating build/temp.macosx-13.0-arm64-3.11/numpy/random
#       creating build/temp.macosx-13.0-arm64-3.11/numpy/random/src
#       creating build/temp.macosx-13.0-arm64-3.11/numpy/random/src/distributions
#       compile options: '-Inumpy/core/include -Ibuild/src.macosx-13.0-arm64-3.11/numpy/core/include/numpy -Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/stevenogwal/development/ml_eng/.venv/include -I/opt/homebrew/Cellar/python@3.11/3.11.10/Frameworks/Python.framework/Versions/3.11/include/python3.11 -Ibuild/src.macosx-13.0-arm64-3.11/numpy/core/src/common -Ibuild/src.macosx-13.0-arm64-3.11/numpy/core/src/npymath -c'
#       clang: numpy/random/src/distributions/distributions.cclang: numpy/random/src/distributions/logfactorial.c
#
#       clang: numpy/random/src/distributions/random_mvhg_count.c
#       clang: numpy/random/src/distributions/random_mvhg_marginals.c
#       clang: numpy/random/src/distributions/random_hypergeometric.c
#       xcrun: adding 5 object files to build/temp.macosx-13.0-arm64-3.11/libnpyrandom.a
#       ranlib:@ build/temp.macosx-13.0-arm64-3.11/libnpyrandom.a
#       running build_ext
#       customize UnixCCompiler
#       customize UnixCCompiler using new_build_ext
#       building 'numpy.core._multiarray_tests' extension
#       compiling C sources
#       C compiler: clang -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -isysroot /Library/Developer/CommandLineTools/SDKs/MacOSX13.sdk
#
#       creating build/temp.macosx-13.0-arm64-3.11/build/src.macosx-13.0-arm64-3.11/numpy/core/src/multiarray
#       creating build/temp.macosx-13.0-arm64-3.11/numpy/core/src/common
#       compile options: '-DNPY_INTERNAL_BUILD=1 -DHAVE_NPY_CONFIG_H=1 -D_FILE_OFFSET_BITS=64 -D_LARGEFILE_SOURCE=1 -D_LARGEFILE64_SOURCE=1 -Inumpy/core/include -Ibuild/src.macosx-13.0-arm64-3.11/numpy/core/include/numpy -Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/stevenogwal/development/ml_eng/.venv/include -I/opt/homebrew/Cellar/python@3.11/3.11.10/Frameworks/Python.framework/Versions/3.11/include/python3.11 -Ibuild/src.macosx-13.0-arm64-3.11/numpy/core/src/common -Ibuild/src.macosx-13.0-arm64-3.11/numpy/core/src/npymath -c'
#       clang: build/src.macosx-13.0-arm64-3.11/numpy/core/src/multiarray/_multiarray_tests.cclang: numpy/core/src/common/mem_overlap.c
#
#       In file included from numpy/core/src/multiarray/_multiarray_tests.c.src:7:
#       In file included from numpy/core/include/numpy/npy_math.h:596:
#       numpy/core/src/npymath/npy_math_internal.h.src:490:21: warning: incompatible pointer types passing 'npy_longdouble *' (aka 'double *') to parameter of type 'long double *' [-Wincompatible-pointer-types]
#           return modfl(x, iptr);
#                           ^~~~
#       /Library/Developer/CommandLineTools/SDKs/MacOSX13.sdk/usr/include/math.h:394:52: note: passing argument to parameter here
#       extern long double modfl(long double, long double *);
#                                                          ^
#       numpy/core/src/multiarray/_multiarray_tests.c.src:1895:61: warning: format specifies type 'long double' but the argument has type 'npy_longdouble' (aka 'double') [-Wformat]
#               PyOS_snprintf(str, sizeof(str), "%.*Lg", precision, x);
#                                                ~~~~~              ^
#                                                %.*g
#       2 warnings generated.
#       clang -bundle -undefined dynamic_lookup -isysroot /Library/Developer/CommandLineTools/SDKs/MacOSX13.sdk build/temp.macosx-13.0-arm64-3.11/build/src.macosx-13.0-arm64-3.11/numpy/core/src/multiarray/_multiarray_tests.o build/temp.macosx-13.0-arm64-3.11/numpy/core/src/common/mem_overlap.o -Lbuild/temp.macosx-13.0-arm64-3.11 -lnpymath -o build/lib.macosx-13.0-arm64-3.11/numpy/core/_multiarray_tests.cpython-311-darwin.so
#       building 'numpy.core._multiarray_umath' extension
#       compiling C sources
#       C compiler: clang -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -isysroot /Library/Developer/CommandLineTools/SDKs/MacOSX13.sdk
#
#       creating build/temp.macosx-13.0-arm64-3.11/numpy/core/src/multiarray
#       creating build/temp.macosx-13.0-arm64-3.11/numpy/core/src/umath
#       creating build/temp.macosx-13.0-arm64-3.11/build/src.macosx-13.0-arm64-3.11/numpy/core/src/umath
#       creating build/temp.macosx-13.0-arm64-3.11/build/src.macosx-13.0-arm64-3.11/numpy/core/src/common
#       creating build/temp.macosx-13.0-arm64-3.11/private
#       creating build/temp.macosx-13.0-arm64-3.11/private/var
#       creating build/temp.macosx-13.0-arm64-3.11/private/var/folders
#       creating build/temp.macosx-13.0-arm64-3.11/private/var/folders/ws
#       creating build/temp.macosx-13.0-arm64-3.11/private/var/folders/ws/c9l_s4sn6bgdlfczk2h4scbr0000gn
#       creating build/temp.macosx-13.0-arm64-3.11/private/var/folders/ws/c9l_s4sn6bgdlfczk2h4scbr0000gn/T
#       creating build/temp.macosx-13.0-arm64-3.11/private/var/folders/ws/c9l_s4sn6bgdlfczk2h4scbr0000gn/T/pip-install-4uqa4xmi
#       creating build/temp.macosx-13.0-arm64-3.11/private/var/folders/ws/c9l_s4sn6bgdlfczk2h4scbr0000gn/T/pip-install-4uqa4xmi/numpy_b3446e2220fa4ba29328f4250f7747f6
#       creating build/temp.macosx-13.0-arm64-3.11/private/var/folders/ws/c9l_s4sn6bgdlfczk2h4scbr0000gn/T/pip-install-4uqa4xmi/numpy_b3446e2220fa4ba29328f4250f7747f6/numpy
#       creating build/temp.macosx-13.0-arm64-3.11/private/var/folders/ws/c9l_s4sn6bgdlfczk2h4scbr0000gn/T/pip-install-4uqa4xmi/numpy_b3446e2220fa4ba29328f4250f7747f6/numpy/_build_utils
#       creating build/temp.macosx-13.0-arm64-3.11/private/var/folders/ws/c9l_s4sn6bgdlfczk2h4scbr0000gn/T/pip-install-4uqa4xmi/numpy_b3446e2220fa4ba29328f4250f7747f6/numpy/_build_utils/src
#       compile options: '-DNPY_INTERNAL_BUILD=1 -DHAVE_NPY_CONFIG_H=1 -D_FILE_OFFSET_BITS=64 -D_LARGEFILE_SOURCE=1 -D_LARGEFILE64_SOURCE=1 -DNO_ATLAS_INFO=3 -DHAVE_CBLAS -Ibuild/src.macosx-13.0-arm64-3.11/numpy/core/src/umath -Ibuild/src.macosx-13.0-arm64-3.11/numpy/core/src/npymath -Ibuild/src.macosx-13.0-arm64-3.11/numpy/core/src/common -Inumpy/core/include -Ibuild/src.macosx-13.0-arm64-3.11/numpy/core/include/numpy -Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/stevenogwal/development/ml_eng/.venv/include -I/opt/homebrew/Cellar/python@3.11/3.11.10/Frameworks/Python.framework/Versions/3.11/include/python3.11 -Ibuild/src.macosx-13.0-arm64-3.11/numpy/core/src/common -Ibuild/src.macosx-13.0-arm64-3.11/numpy/core/src/npymath -c'
#       extra options: '-faltivec -I/System/Library/Frameworks/vecLib.framework/Headers'
#       clang: numpy/core/src/multiarray/alloc.c
#       clang: numpy/core/src/multiarray/buffer.cclang: numpy/core/src/multiarray/array_assign_scalar.c
#
#       clang: numpy/core/src/multiarray/common.c
#       clang: numpy/core/src/multiarray/conversion_utils.c
#       clang: numpy/core/src/multiarray/descriptor.c
#       clang: numpy/core/src/multiarray/datetime_strings.c
#       clang: build/src.macosx-13.0-arm64-3.11/numpy/core/src/multiarray/einsum.c
#       clang: error: the clang compiler does not support 'faltivec', please use -maltivec and include altivec.h explicitly
#       clang: error: the clang compiler does not support 'faltivec', please use -maltivec and include altivec.h explicitly
#       clang: numpy/core/src/multiarray/hashdescr.c
#       clang: error: the clang compiler does not support 'faltivec', please use -maltivec and include altivec.h explicitly
#       clang: build/src.macosx-13.0-arm64-3.11/numpy/core/src/multiarray/lowlevel_strided_loops.c
#       clang: error: the clang compiler does not support 'faltivec', please use -maltivec and include altivec.h explicitly
#       clang: error: the clang compiler does not support 'faltivec', please use -maltivec and include altivec.h explicitly
#       clang: numpy/core/src/multiarray/multiarraymodule.c
#       clang: numpy/core/src/multiarray/nditer_constr.c
#       clang: error: the clang compiler does not support 'faltivec', please use -maltivec and include altivec.h explicitly
#       clang: error: the clang compiler does not support 'faltivec', please use -maltivec and include altivec.h explicitly
#       clang: numpy/core/src/multiarray/refcount.c
#       clang: error: the clang compiler does not support 'faltivec', please use -maltivec and include altivec.h explicitly
#       clang: numpy/core/src/multiarray/scalarapi.c
#       clang: numpy/core/src/multiarray/vdot.cclang: numpy/core/src/multiarray/temp_elide.c
#
#       clang: error: the clang compiler does not support 'faltivec', please use -maltivec and include altivec.h explicitly
#       clang: error: the clang compiler does not support 'faltivec', please use -maltivec and include altivec.h explicitly
#       clang: error: the clang compiler does not support 'faltivec', please use -maltivec and include altivec.h explicitly
#       clang: build/src.macosx-13.0-arm64-3.11/numpy/core/src/umath/loops.c
#       clang: error: the clang compiler does not support 'faltivec', please use -maltivec and include altivec.h explicitly
#       clang: error: the clang compiler does not support 'faltivec', please use -maltivec and include altivec.h explicitly
#       clang: numpy/core/src/umath/ufunc_object.c
#       clang: error: the clang compiler does not support 'faltivec', please use -maltivec and include altivec.h explicitly
#       clang: error: the clang compiler does not support 'faltivec', please use -maltivec and include altivec.h explicitly
#       clang: numpy/core/src/umath/ufunc_type_resolution.c
#       clang: numpy/core/src/common/array_assign.cclang: error: the clang compiler does not support 'faltivec', please use -maltivec and include altivec.h explicitly
#
#       clang: numpy/core/src/common/ucsnarrow.cclang: build/src.macosx-13.0-arm64-3.11/numpy/core/src/common/npy_cpu_features.c
#
#       clang: build/src.macosx-13.0-arm64-3.11/numpy/core/src/npymath/ieee754.cclang: /private/var/folders/ws/c9l_s4sn6bgdlfczk2h4scbr0000gn/T/pip-install-4uqa4xmi/numpy_b3446e2220fa4ba29328f4250f7747f6/numpy/_build_utils/src/apple_sgemv_fix.c
#
#       clang: error: the clang compiler does not support 'faltivec', please use -maltivec and include altivec.h explicitly
#       clang: error: the clang compiler does not support 'faltivec', please use -maltivec and include altivec.h explicitly
#       clang: error: the clang compiler does not support 'faltivec', please use -maltivec and include altivec.h explicitly
#       clang: error: the clang compiler does not support 'faltivec', please use -maltivec and include altivec.h explicitly
#       clang: error: the clang compiler does not support 'faltivec', please use -maltivec and include altivec.h explicitly
#       clang: error: the clang compiler does not support 'faltivec', please use -maltivec and include altivec.h explicitly
#       clang: error: the clang compiler does not support 'faltivec', please use -maltivec and include altivec.h explicitly
#       clang: error: the clang compiler does not support 'faltivec', please use -maltivec and include altivec.h explicitly
#       error: Command "clang -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -isysroot /Library/Developer/CommandLineTools/SDKs/MacOSX13.sdk -DNPY_INTERNAL_BUILD=1 -DHAVE_NPY_CONFIG_H=1 -D_FILE_OFFSET_BITS=64 -D_LARGEFILE_SOURCE=1 -D_LARGEFILE64_SOURCE=1 -DNO_ATLAS_INFO=3 -DHAVE_CBLAS -Ibuild/src.macosx-13.0-arm64-3.11/numpy/core/src/umath -Ibuild/src.macosx-13.0-arm64-3.11/numpy/core/src/npymath -Ibuild/src.macosx-13.0-arm64-3.11/numpy/core/src/common -Inumpy/core/include -Ibuild/src.macosx-13.0-arm64-3.11/numpy/core/include/numpy -Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/Users/stevenogwal/development/ml_eng/.venv/include -I/opt/homebrew/Cellar/python@3.11/3.11.10/Frameworks/Python.framework/Versions/3.11/include/python3.11 -Ibuild/src.macosx-13.0-arm64-3.11/numpy/core/src/common -Ibuild/src.macosx-13.0-arm64-3.11/numpy/core/src/npymath -c numpy/core/src/multiarray/buffer.c -o build/temp.macosx-13.0-arm64-3.11/numpy/core/src/multiarray/buffer.o -MMD -MF build/temp.macosx-13.0-arm64-3.11/numpy/core/src/multiarray/buffer.o.d -faltivec -I/System/Library/Frameworks/vecLib.framework/Headers" failed with exit status 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for numpy
# Failed to build numpy
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (numpy)

# %%
import findspark
findspark.init()

# %%
import pandas as pd
from pyspark import SparkContext, SparkConf
from pyspark.sql import SparkSession

# %% [markdown]
# ## Exercise 1 -  Spark session

# %% [markdown]
# Create and initialize the Spark session needed to load the data frames and operate on it

# %% [markdown]
# #### Task 1: Creating the spark session and context

# %%
# Creating a spark context class
sc = SparkContext()

# Creating a spark session
spark = SparkSession \
    .builder \
    .appName("Python Spark DataFrames basic example") \
    .config("spark.some.config.option", "some-value") \
    .getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/10/01 09:01:38 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 24/10/01 09:01:38 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 24/10/01 09:01:38 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.

# %% [markdown]
# #### Task 2: Initialize Spark session
# To work with dataframes we just need to verify that the spark session instance has been created.

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.1.64:4042">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## Exercise 2 - Loading the Data and creating a table view

# %% [markdown]
# In this section, you will first read the CSV file into a Pandas Dataframe and then read it into a Spark Dataframe
# Pandas is a library used for data manipulation and analysis. The Pandas library offers data structures and operations for creating and manipulating Data Series and DataFrame objects. Data can be imported from various data sources, e.g., Numpy arrays, Python dictionaries, and CSV files. Pandas allows you to manipulate, organize and display the data.
#
# To create a Spark DataFrame we load an external DataFrame, called `mtcars`. This DataFrame includes 32 observations on 11 variables:
#
# | colIndex | colName | units/description |
# | :---: | :--- | :--- |
# |[, 1] | mpg |Miles per gallon  |
# |[, 2] | cyl | Number of cylinders  |
# |[, 3] | disp | Displacement (cu.in.) |
# |[, 4] | hp  | Gross horsepower  |
# |[, 5] | drat | Rear axle ratio  |
# |[, 6] | wt | Weight (lb/1000)  |
# |[, 7] | qsec | 1/4 mile time  |
# |[, 8] | vs  | V/S  |
# |[, 9] | am | Transmission (0 = automatic, 1 = manual)  |
# |[,10] | gear | Number of forward gears  |
# |[,11] | carb | Number of carburetors |

# %% [markdown]
# #### Task 1: Load data into a Pandas DataFrame.
#
# Pandas has a convenient function to load CSV data from a URL directly into a pandas dataframe.

# %%
# Read the file using `read_csv` function in pandas
mtcars = pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-BD0225EN-SkillsNetwork/labs/data/mtcars.csv')

# %%
# Preview a few records
mtcars.head()
# Out:
#           Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
mtcars.rename( columns={'Unnamed: 0':'name'}, inplace=True )

# %% [markdown]
# #### Task 2: Loading data into a Spark DataFrame

# %% [markdown]
# We use the `createDataFrame` function to load the data into a spark dataframe

# %%
sdf = spark.createDataFrame(mtcars)

# %% [markdown]
# Let us look at the schema of the loaded spark dataframe

# %%
sdf.printSchema()
# Out:
# root
#  |-- name: string (nullable = true)
#  |-- mpg: double (nullable = true)
#  |-- cyl: long (nullable = true)
#  |-- disp: double (nullable = true)
#  |-- hp: long (nullable = true)
#  |-- drat: double (nullable = true)
#  |-- wt: double (nullable = true)
#  |-- qsec: double (nullable = true)
#  |-- vs: long (nullable = true)
#  |-- am: long (nullable = true)
#  |-- gear: long (nullable = true)
#  |-- carb: long (nullable = true)

# %% [markdown]
# #### Task 3: Rename the existing column name "vs" to "versus" and assign the new result DataFrame to a variable, "sdf_new".
#
# The function `withColumnRenamed()` is renames the existing column names.

# %%
sdf_new = sdf.withColumnRenamed("vs", "versus")

# %% [markdown]
# The execution of the above function doesn’t modify the original DataFrame `sdf`, instead, a new DataFrame `sdf_new` is created with the renamed column.

# %% [markdown]
# #### Task 4: View the new dataframe

# %%
sdf_new.head(5)
# Out:
# [Row(name='Mazda RX4', mpg=21.0, cyl=6, disp=160.0, hp=110, drat=3.9, wt=2.62, qsec=16.46, versus=0, am=1, gear=4, carb=4),
#  Row(name='Mazda RX4 Wag', mpg=21.0, cyl=6, disp=160.0, hp=110, drat=3.9, wt=2.875, qsec=17.02, versus=0, am=1, gear=4, carb=4),
#  Row(name='Datsun 710', mpg=22.8, cyl=4, disp=108.0, hp=93, drat=3.85, wt=2.32, qsec=18.61, versus=1, am=1, gear=4, carb=1),
#  Row(name='Hornet 4 Drive', mpg=21.4, cyl=6, disp=258.0, hp=110, drat=3.08, wt=3.215, qsec=19.44, versus=1, am=0, gear=3, carb=1),
#  Row(name='Hornet Sportabout', mpg=18.7, cyl=8, disp=360.0, hp=175, drat=3.15, wt=3.44, qsec=17.02, versus=0, am=0, gear=3, carb=2)]

# %% [markdown]
# Observe how `vs` has now been renamed to `versus` in this dataframe.

# %% [markdown]
# #### Task 4: Create a Table View
# Creating a table view in Spark SQL is required to run SQL queries programmatically on a DataFrame. A view is a temporary table to run SQL queries. A Temporary view provides local scope within the current Spark session. In this example we create a temporary view using the `createTempView()` function

# %%
sdf.createTempView("cars")

# %% [markdown]
# ## Exercise 3 - Running SQL queries and aggregating data

# %% [markdown]
# Once we have a table view, we can run queries similar to querying a SQL table. We perform similar operations to the ones in the DataFrames notebook. Note the difference here however is that we use the SQL queries directly.

# %%
# Showing the whole table
spark.sql("SELECT * FROM cars").show()
# Out:
# +-------------------+----+---+-----+---+----+-----+-----+---+---+----+----+
# |               name| mpg|cyl| disp| hp|drat|   wt| qsec| vs| am|gear|carb|
# +-------------------+----+---+-----+---+----+-----+-----+---+---+----+----+
# |          Mazda RX4|21.0|  6|160.0|110| 3.9| 2.62|16.46|  0|  1|   4|   4|
# |      Mazda RX4 Wag|21.0|  6|160.0|110| 3.9|2.875|17.02|  0|  1|   4|   4|
# |         Datsun 710|22.8|  4|108.0| 93|3.85| 2.32|18.61|  1|  1|   4|   1|
# |     Hornet 4 Drive|21.4|  6|258.0|110|3.08|3.215|19.44|  1|  0|   3|   1|
# |  Hornet Sportabout|18.7|  8|360.0|175|3.15| 3.44|17.02|  0|  0|   3|   2|
# |            Valiant|18.1|  6|225.0|105|2.76| 3.46|20.22|  1|  0|   3|   1|
# |         Duster 360|14.3|  8|360.0|245|3.21| 3.57|15.84|  0|  0|   3|   4|
# |          Merc 240D|24.4|  4|146.7| 62|3.69| 3.19| 20.0|  1|  0|   4|   2|
# |           Merc 230|22.8|  4|140.8| 95|3.92| 3.15| 22.9|  1|  0|   4|   2|
# |           Merc 280|19.2|  6|167.6|123|3.92| 3.44| 18.3|  1|  0|   4|   4|
# |          Merc 280C|17.8|  6|167.6|123|3.92| 3.44| 18.9|  1|  0|   4|   4|
# |         Merc 450SE|16.4|  8|275.8|180|3.07| 4.07| 17.4|  0|  0|   3|   3|
# |         Merc 450SL|17.3|  8|275.8|180|3.07| 3.73| 17.6|  0|  0|   3|   3|
# |        Merc 450SLC|15.2|  8|275.8|180|3.07| 3.78| 18.0|  0|  0|   3|   3|
# | Cadillac Fleetwood|10.4|  8|472.0|205|2.93| 5.25|17.98|  0|  0|   3|   4|
# |Lincoln Continental|10.4|  8|460.0|215| 3.0|5.424|17.82|  0|  0|   3|   4|
# |  Chrysler Imperial|14.7|  8|440.0|230|3.23|5.345|17.42|  0|  0|   3|   4|
# |           Fiat 128|32.4|  4| 78.7| 66|4.08|  2.2|19.47|  1|  1|   4|   1|
# |        Honda Civic|30.4|  4| 75.7| 52|4.93|1.615|18.52|  1|  1|   4|   2|
# |     Toyota Corolla|33.9|  4| 71.1| 65|4.22|1.835| 19.9|  1|  1|   4|   1|
# +-------------------+----+---+-----+---+----+-----+-----+---+---+----+----+
# only showing top 20 rows

# %%
# Showing a specific column
spark.sql("SELECT mpg FROM cars").show(5)
# Out:
# +----+
# | mpg|
# +----+
# |21.0|
# |21.0|
# |22.8|
# |21.4|
# |18.7|
# +----+
# only showing top 5 rows

# %%
# Basic filtering query to determine cars that have a high mileage and low cylinder count
spark.sql("SELECT * FROM cars where mpg>20 AND cyl < 6").show(5)
# Out:
# +-----------+----+---+-----+---+----+-----+-----+---+---+----+----+
# |       name| mpg|cyl| disp| hp|drat|   wt| qsec| vs| am|gear|carb|
# +-----------+----+---+-----+---+----+-----+-----+---+---+----+----+
# | Datsun 710|22.8|  4|108.0| 93|3.85| 2.32|18.61|  1|  1|   4|   1|
# |  Merc 240D|24.4|  4|146.7| 62|3.69| 3.19| 20.0|  1|  0|   4|   2|
# |   Merc 230|22.8|  4|140.8| 95|3.92| 3.15| 22.9|  1|  0|   4|   2|
# |   Fiat 128|32.4|  4| 78.7| 66|4.08|  2.2|19.47|  1|  1|   4|   1|
# |Honda Civic|30.4|  4| 75.7| 52|4.93|1.615|18.52|  1|  1|   4|   2|
# +-----------+----+---+-----+---+----+-----+-----+---+---+----+----+
# only showing top 5 rows

# %%
# Use where method to get list of cars that have miles per gallon is less than 18
sdf.where(sdf['mpg'] < 18).show(3)
# Out:
# +----------+----+---+-----+---+----+----+-----+---+---+----+----+
# |      name| mpg|cyl| disp| hp|drat|  wt| qsec| vs| am|gear|carb|
# +----------+----+---+-----+---+----+----+-----+---+---+----+----+
# |Duster 360|14.3|  8|360.0|245|3.21|3.57|15.84|  0|  0|   3|   4|
# | Merc 280C|17.8|  6|167.6|123|3.92|3.44| 18.9|  1|  0|   4|   4|
# |Merc 450SE|16.4|  8|275.8|180|3.07|4.07| 17.4|  0|  0|   3|   3|
# +----------+----+---+-----+---+----+----+-----+---+---+----+----+
# only showing top 3 rows

# %%
# Aggregating data and grouping by cylinders
spark.sql("SELECT count(*), cyl from cars GROUP BY cyl").show()
# Out:
# +--------+---+
# |count(1)|cyl|
# +--------+---+
# |       7|  6|
# |      11|  4|
# |      14|  8|
# +--------+---+

# %% [markdown]
# ## Exercise 4 - Create a Pandas UDF to apply a columnar operation
# Apache Spark has become the de-facto standard in processing big data. To enable data scientists to leverage the value of big data, Spark added a Python API in version 0.7, with support for user-defined functions (UDF). These user-defined functions operate one-row-at-a-time, and thus suffer from high serialization and invocation overhead. As a result, many data pipelines define UDFs in Java and Scala and then invoke them from Python.
#
# Pandas UDFs built on top of Apache Arrow bring you the _best of both worlds_—the ability to define low-overhead, high-performance UDFs entirely in Python. In this simple example, we will build a Scalar Pandas UDF to convert the wT column from imperial units (1000-lbs) to metric units (metric tons).
#
# In addition, UDFs can be registered and invoked in SQL out of the box by registering a regular python function using the `@pandas_udf()` decorator. We can then apply this UDF to our `wt` column.

# %% [markdown]
# #### Task 1: Importing libraries and registering a UDF

# %%
# import the Pandas UDF function 
from pyspark.sql.functions import pandas_udf, PandasUDFType

# %%
@pandas_udf("float")
def convert_wt(s: pd.Series) -> pd.Series:
    # The formula for converting from imperial to metric tons
    return s * 0.45

spark.udf.register("convert_weight", convert_wt)

# %% [markdown]
# #### Task 2: Applying the UDF to the tableview
#
# We can now apply the `convert_weight` user-defined-function to our `wt` column from the `cars` table view. This is done very simply using the SQL query shown below. In this example below we show both the original weight (in ton-lbs) and converted weight (in metric tons).

# %%
spark.sql("SELECT *, wt AS weight_imperial, convert_weight(wt) as weight_metric FROM cars").show()
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 spark.sql("SELECT *, wt AS weight_imperial, convert_weight(wt) as weight_metric FROM cars").show()
#
# File ~/development/ml_eng/.venv/lib/python3.11/site-packages/pyspark/sql/session.py:1631, in SparkSession.sql(self, sqlQuery, args, **kwargs)
#    1627         assert self._jvm is not None
#    1628         litArgs = self._jvm.PythonUtils.toArray(
#    1629             [_to_java_column(lit(v)) for v in (args or [])]
#    1630         )
# -> 1631     return DataFrame(self._jsparkSession.sql(sqlQuery, litArgs), self)
#    1632 finally:
#    1633     if len(kwargs) > 0:
#
# File ~/development/ml_eng/.venv/lib/python3.11/site-packages/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File ~/development/ml_eng/.venv/lib/python3.11/site-packages/pyspark/errors/exceptions/captured.py:185, in capture_sql_exception.<locals>.deco(*a, **kw)
#     181 converted = convert_exception(e.java_exception)
#     182 if not isinstance(converted, UnknownException):
#     183     # Hide where the exception came from that shows a non-Pythonic
#     184     # JVM exception message.
# --> 185     raise converted from None
#     186 else:
#     187     raise
#
# AnalysisException: [UNRESOLVED_ROUTINE] Cannot resolve function `convert_weight` on search path [`system`.`builtin`, `system`.`session`, `spark_catalog`.`default`].; line 1 pos 33

# %% [markdown]
# ## Exercise 5 - Combining DataFrames based on a specific condition.

# %% [markdown]
# #### Task 1 - Understanding JOIN operation

# %%
# define sample DataFrame 1 

data = [("A101", "John"), ("A102", "Peter"), ("A103", "Charlie")] 

columns = ["emp_id", "emp_name"]

dataframe_1 = spark.createDataFrame(data, columns)

# %%
# define sample DataFrame 2

data = [("A101", 3250), ("A102", 6735), ("A103", 8650)] 

columns = ["emp_id", "salary"] 

dataframe_2 = spark.createDataFrame(data, columns)

# %%
# create a new DataFrame, "combined_df" by performing an inner join 

combined_df = dataframe_1.join(dataframe_2, on="emp_id", how="inner")

# %%
# Show the data in combined_df as a list of Row.

combined_df.collect()

# %% [markdown]
# #### Task 2 Filling the missing values

# %%
# define sample DataFrame 1 with some missing values

data = [("A101", 1000), ("A102", 2000), ("A103",None)]

columns = ["emp_id", "salary"]

dataframe_1 = spark.createDataFrame(data, columns)

# %%
dataframe_1.head(3)

# %% [markdown]
# You will see that an error is thrown as the dataframe has null value.

# %% [markdown]
# Note that the third record of the DataFrame "dataframe_1", the column “salary”, contains null("na") value. It can be filled with a value by using the function "fillna()".

# %%
# fill missing salary value with a specified value

filled_df = dataframe_1.fillna({"salary": 3000})

# %%
filled_df.head(3)

# %% [markdown]
# ### Practice Questions

# %% [markdown]
# ### Question 1 - Basic SQL operations

# %% [markdown]
# Display all Mercedez car rows from the `cars` table view we created earlier. The Mercedez cars have the prefix "Merc" in the car name column.

# %%
# Code block for learners to answer

# %% [markdown]
# Double-click **here** for a hint.
#
# <!-- The hint is below:
#
# The SQL query word `like` is used to identify patterns.
#
# -->

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- The answer is below:
#
# spark.sql("SELECT * FROM cars where name like 'Merc%'").show()
#
# -->

# %% [markdown]
# ### Question 2 - User Defined Functions

# %% [markdown]
# In this notebook, we created a UDF to convert weight from imperial to metric units. Now for this exercise, please create a pandas UDF to convert the `mpg` column to `kmpl` (kilometers per liter). You can use the conversion factor of 0.425.

# %%
# Code block for learners to answer
from pyspark.sql.functions import pandas_udf

@pandas_udf("float")
def convert_mileage(s: pd.Series) -> pd.Series:
    # The formula for converting from imperial to metric tons
    return s * 0.425

spark.udf.register("convert_mileage", convert_mileage)

spark.sql("SELECT *, mpg AS mpg, convert_mileage(mpg) as kmpl FROM cars").show()

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- The answer is below:
# from pyspark.sql.functions import pandas_udf
#
# @pandas_udf("float")
# def convert_mileage(s: pd.Series) -> pd.Series:
#     # The formula for converting from imperial to metric tons
#     return s * 0.425
#
# spark.udf.register("convert_mileage", convert_mileage)
#
# spark.sql("SELECT *, mpg AS mpg, convert_mileage(mpg) as kmpl FROM cars").show()
# -->

# %% [markdown]
# ## Authors

# %% [markdown]
# [Karthik Muthuraman](https://www.linkedin.com/in/karthik-muthuraman/)

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# [Jerome Nilmeier](https://github.com/nilmeier)

# %% [markdown]
# <!--## Change Log -->

# %% [markdown]
# <!--|Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2023-10-16|0.4|K Sundararajan |Minor updates for clarity|
# |2022-09-13|0.3|K Sundararajan|Pyarrow version changed to `0.1.4.1`|
# |2021-07-02|0.2|Karthik|Beta launch|
# |2021-06-30|0.1|Karthik|First Draft|-->

# %% [markdown]
# <h3 align="center"> &#169; IBM Corporation. All rights reserved. <h3/>
