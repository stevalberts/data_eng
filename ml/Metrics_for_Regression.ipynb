# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# ## Metrics for Regression

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# <p style='color: red'>The purpose of this lab is to show you how to evaluate a regression model using various metrics.</p>

# %% [markdown]
# ## __Table of Contents__
#
# <ol>
#     <li><a href="#Objectives">Objectives</a></li>
#     <li><a href="#Datasets">Datasets</a></li>
#     <li>
#         <a href="#Setup">Setup</a>
#         <ol>
#             <li><a href="#Installing-Required-Libraries">Installing Required Libraries</a></li>
#             <li><a href="#Importing-Required-Libraries">Importing Required Libraries</a></li>
#         </ol>
#     </li>
#     <li>
#         <a href="#Examples">Examples</a>
#         <ol>
#             <li><a href="#Task-1---Load-the-data-in-a-csv-file-into-a-dataframe">Task 1 - Load the data in a csv file into a dataframe</a></li>
#     <li><a href="#Task-2---Identify-the-target-column-and-the-data-columns">Task 2 - Identify the target column and the data columns</a></li>
# <li><a href="#Task-3---Split-the-data-set">Task 3 - Split the data set</a></li>
#     <li><a href="#Task-4---Build-and-Train-a-Linear-Regression-Model">Task 4 - Build and Train a Linear Regression Model</a></li>
#         <li><a href="#Task-5---Evaluate-the-model">Task 5 - Evaluate the model</a></li>
#         </ol>
#     </li>
#
#
#
# <li><a href="#Exercises">Exercises</a></li>
# <ol>
#     <li><a href="#Exercise-1---Loading-a-dataset-(diamond-dataset)">Exercise 1 - Loading a dataset (diamond dataset)</a></li>
#     <li><a href="#Exercise-2---Identify-the-target-column-and-the-data-columns">Exercise 2 - Identify the target column and the data columns</a></li>
#     <li><a href="#Exercise-3---Split-the-data">Exercise 3 - Split the data</a></li>
#     <li><a href="#Exercise-4---Predict-values">Exercise 4 - Predict values</a></li>
#     <li><a href="#Exercise-5---Evaluate-the-model">Exercise 5 - Evaluate the model</a></li>
#     </ol>
# </ol>

# %% [markdown]
# ## Objectives
#
# After completing this lab you will be able to:
#
#  - Use Pandas to load data sets.
#  - Identify the target and features.
#  - Split the dataset into training and testing sets.
#  - Use Linear Regression to build a prediction model.
#  - Use metrics to evaluate the model.

# %% [markdown]
# ## Datasets
#
# In this lab you will be using dataset(s):
#
#  - Modified version of car mileage dataset. Original dataset available at https://archive.ics.uci.edu/ml/datasets/auto+mpg
#  - Modified version of diamonds dataset. Original dataset available at https://www.openml.org/search?type=data&sort=runs&id=42225&status=active

# %% [markdown]
# ----

# %% [markdown]
# ## Setup

# %% [markdown]
# For this lab, we will be using the following libraries:
#
# *   [`pandas`](https://pandas.pydata.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for managing the data.
# *   [`sklearn`](https://scikit-learn.org/stable/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for machine learning and machine-learning-pipeline related functions.

# %% [markdown]
# ### Installing Required Libraries
#
# The following required libraries are pre-installed in the Skills Network Labs environment. However, if you run this notebook commands in a different Jupyter environment (e.g. Watson Studio or Ananconda), you will need to install these libraries by removing the `#` sign before `!pip` in the code cell below.

# %%
# All Libraries required for this lab are listed below. The libraries pre-installed on Skills Network Labs are commented.
# !pip install pandas
# !pip install scikit-learn
# !pip install numpy
# Out:
# Requirement already satisfied: pandas in /Users/stevenogwal/development/ml_eng/.venv/lib/python3.11/site-packages (1.3.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/stevenogwal/development/ml_eng/.venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2017.3 in /Users/stevenogwal/development/ml_eng/.venv/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /Users/stevenogwal/development/ml_eng/.venv/lib/python3.11/site-packages (from pandas) (2.1.0)
# Requirement already satisfied: six>=1.5 in /Users/stevenogwal/development/ml_eng/.venv/lib/python3.11/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Requirement already satisfied: scikit-learn in /Users/stevenogwal/development/ml_eng/.venv/lib/python3.11/site-packages (1.5.2)
# Requirement already satisfied: numpy>=1.19.5 in /Users/stevenogwal/development/ml_eng/.venv/lib/python3.11/site-packages (from scikit-learn) (2.1.0)
# Requirement already satisfied: scipy>=1.6.0 in /Users/stevenogwal/development/ml_eng/.venv/lib/python3.11/site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/stevenogwal/development/ml_eng/.venv/lib/python3.11/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/stevenogwal/development/ml_eng/.venv/lib/python3.11/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: numpy in /Users/stevenogwal/development/ml_eng/.venv/lib/python3.11/site-packages (2.1.0)

# %%
# You can use this section to suppress warnings generated by your code:
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Importing Required Libraries
#
# _We recommend you import all required libraries in one place (here):_

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

#import functions for train test split

from sklearn.model_selection import train_test_split

# import functions for metrics
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from math import sqrt
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import pandas as pd
#       2 from sklearn.linear_model import LinearRegression
#       4 #import functions for train test split
#
# File ~/development/ml_eng/.venv/lib/python3.11/site-packages/pandas/__init__.py:22
#      19 del hard_dependencies, dependency, missing_dependencies
#      21 # numpy compat
# ---> 22 from pandas.compat import (
#      23     np_version_under1p18 as _np_version_under1p18,
#      24     is_numpy_dev as _is_numpy_dev,
#      25 )
#      27 try:
#      28     from pandas._libs import hashtable as _hashtable, lib as _lib, tslib as _tslib
#
# File ~/development/ml_eng/.venv/lib/python3.11/site-packages/pandas/compat/__init__.py:15
#      12 import warnings
#      14 from pandas._typing import F
# ---> 15 from pandas.compat.numpy import (
#      16     is_numpy_dev,
#      17     np_array_datetime64_compat,
#      18     np_datetime64_compat,
#      19     np_version_under1p18,
#      20     np_version_under1p19,
#      21     np_version_under1p20,
#      22 )
#      23 from pandas.compat.pyarrow import (
#      24     pa_version_under1p0,
#      25     pa_version_under2p0,
#      26     pa_version_under3p0,
#      27     pa_version_under4p0,
#      28 )
#      30 PY38 = sys.version_info >= (3, 8)
#
# File ~/development/ml_eng/.venv/lib/python3.11/site-packages/pandas/compat/numpy/__init__.py:7
#       3 import re
#       5 import numpy as np
# ----> 7 from pandas.util.version import Version
#       9 # numpy versioning
#      10 _np_version = np.__version__
#
# File ~/development/ml_eng/.venv/lib/python3.11/site-packages/pandas/util/__init__.py:1
# ----> 1 from pandas.util._decorators import (  # noqa
#       2     Appender,
#       3     Substitution,
#       4     cache_readonly,
#       5 )
#       7 from pandas.core.util.hashing import (  # noqa
#       8     hash_array,
#       9     hash_pandas_object,
#      10 )
#      13 def __getattr__(name):
#
# File ~/development/ml_eng/.venv/lib/python3.11/site-packages/pandas/util/_decorators.py:14
#       6 from typing import (
#       7     Any,
#       8     Callable,
#       9     Mapping,
#      10     cast,
#      11 )
#      12 import warnings
# ---> 14 from pandas._libs.properties import cache_readonly  # noqa
#      15 from pandas._typing import F
#      18 def deprecate(
#      19     name: str,
#      20     alternative: Callable[..., Any],
#    (...)
#      25     msg: str | None = None,
#      26 ) -> Callable[[F], F]:
#
# File ~/development/ml_eng/.venv/lib/python3.11/site-packages/pandas/_libs/__init__.py:13
#       1 __all__ = [
#       2     "NaT",
#       3     "NaTType",
#    (...)
#       9     "Interval",
#      10 ]
# ---> 13 from pandas._libs.interval import Interval
#      14 from pandas._libs.tslibs import (
#      15     NaT,
#      16     NaTType,
#    (...)
#      21     iNaT,
#      22 )
#
# File ~/development/ml_eng/.venv/lib/python3.11/site-packages/pandas/_libs/interval.pyx:1, in init pandas._libs.interval()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject

# %% [markdown]
# ## Task 1 - Load the data in a csv file into a dataframe

# %%
# the data set is available at the url below.
URL = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-BD0231EN-SkillsNetwork/datasets/mpg.csv"

# using the read_csv function in the pandas library, we load the data into a dataframe.

df = pd.read_csv(URL)

# %% [markdown]
# Let's look at some sample rows from the dataset we loaded:

# %%
# show 5 random rows from the dataset
df.sample(5)

# %% [markdown]
# Let's find out the number of rows and columns in the dataset:

# %%
df.shape

# %% [markdown]
# Let's create a scatter plot of Weight versus mileage(MPG) . This will help us visualize the relationship between them.

# %%
df.plot.scatter(x = "Weight", y = "MPG")

# %% [markdown]
# You are encouraged to create more plots to visualize relationships amongst other columns

# %% [markdown]
# ## Task 2 - Identify the target column and the data columns

# %% [markdown]
# First we identify the target. Target is the value that our machine learning model needs to predict

# %%
y = df["MPG"] # y is the target

# %% [markdown]
# We identify the features next. Features are the values our machine learning model learns from

# %%
X = df[["Horsepower","Weight"]] # X is the set of features

# %% [markdown]
# ## Task 3 - Split the data set

# %% [markdown]
# We split the data set in the ratio of 70:30. 70% training data, 30% testing data.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %% [markdown]
# The random_state variable controls the shuffling applied to the data before applying the split. Pass the same integer for reproducible output across multiple function calls

# %% [markdown]
# ## Task 4 - Build and Train a Linear Regression Model

# %% [markdown]
# Create a LR model

# %%
lr = LinearRegression()

# %% [markdown]
# Train/Fit the model using the training data set

# %%
lr.fit(X_train,y_train)

# %% [markdown]
# ## Task 5 - Evaluate the model

# %% [markdown]
# Your model is now trained. We use the testing data to evaluate the model.

# %%
lr.score(X_test, y_test)

# %% [markdown]
# To compute the detailed metrics we need two values, the original mileage and the predicted mileage.

# %%
original_values = y_test
predicted_values = lr.predict(X_test)

# %% [markdown]
# ##### R Squared

# %%
r2_score(original_values, predicted_values) # Higher the value the better the model

# %% [markdown]
# ##### Mean Squared Error

# %%
mean_squared_error(original_values, predicted_values) # Lower the value the better the model

# %% [markdown]
# ##### Root Mean Squared Error

# %%
sqrt(mean_squared_error(original_values, predicted_values)) # Lower the value the better the model

# %% [markdown]
# ##### Mean Absolute Error

# %%
mean_absolute_error(original_values, predicted_values) # Lower the value the better the model

# %% [markdown]
# # Exercises

# %%
URL2 = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-BD0231EN-SkillsNetwork/datasets/diamonds.csv"

# %% [markdown]
# ### Exercise 1 - Loading a dataset (diamond dataset)

# %%
df2 = # TODO

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Use the read_csv function
#
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# df2 = pd.read_csv(URL2)
# ```
#
# </details>

# %% [markdown]
# ### Exercise 2 - Identify the target column and the data columns

# %% [markdown]
#  - Use the price column as target
#  - Use the columns carat, depth and table as features

# %%
y = # TODO
X = # TODO

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Refer to Task 2
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# y = df2["price"]
# X = df2[["carat","depth","table"]]
# ```
#
# </details>

# %% [markdown]
# ### Exercise 3 - Split the data

# %% [markdown]
# Split the dataset into training and testing sets. Make 25% of the data as testing set. Use 42 as random state.

# %%
X_train, X_test, y_train, y_test =#TODO

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Use the train_test_split function
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
#
# ```
#
# </details>

# %% [markdown]
# ### Exercise 4 - Predict values

# %%
lr2 = LinearRegression()
lr2.fit(X_train, y_train)

# %% [markdown]
# Predict the values using the test data.

# %%
original_values = y_test
predicted_values = #TODO

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Use the predict() method
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# original_values = y_test
# predicted_values = lr2.predict(X_test)
#
# ```
#
# </details>

# %% [markdown]
# ### Exercise 5 - Evaluate the model

# %% [markdown]
# Print the metrics :
# - R squared
# - mean absolute error
# - mean squared error
# - root mean squared error

# %%
#your code goes here

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Use the metrics functions </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# print(r2_score(original_values, predicted_values))
# print(mean_absolute_error(original_values, predicted_values))
# print(mean_squared_error(original_values, predicted_values))
# print(sqrt(mean_squared_error(original_values, predicted_values)))
#
# ```
#
# </details>

# %% [markdown]
# Congratulations you have completed this lab.<br>

# %% [markdown]
# ## Authors

# %% [markdown]
# [Ramesh Sannareddy](https://www.linkedin.com/in/rsannareddy/)

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Copyright © 2023 IBM Corporation. All rights reserved.

# %% [markdown]
# <!--
# ## Change Log
# -->

# %% [markdown]
# <!--
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2023-04-15|0.1|Ramesh Sannareddy|Initial Version Created|
# -->
